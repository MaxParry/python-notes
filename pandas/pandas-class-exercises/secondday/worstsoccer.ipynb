# %% [markdown]
# Instructions:
#
#     •	Read in the CSV file provided and print it to the screen
#
#     •	Print out a list of all of the values within the "Preferred Position" column
#
#     •	Select a value from this list and create a new DataFrame that only includes players who prefer that position
#
#     •	Sort the DataFrame based upon a player's skill in that position
#
#     •	Reset the index for the DataFrame so that the index is in order
#
#     •	Print out the statistics for the worst player in a position to the screen

# %%
import pandas as pd
csv = pd.read_csv('../../input_data/soccer.csv', encoding='ISO-8859-1')
df = pd.DataFrame(csv)
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal     94.0       94.0
# 1           L. Messi   30   Argentina     93.0       93.0
# 2             Neymar   25      Brazil     92.0       94.0
# 3         L. SuÃ¡rez   30     Uruguay     92.0       92.0
# 4           M. Neuer   31     Germany     92.0       92.0
#
#                   Club Preferred Position   CAM    CB   CDM  ...     RB   RCB  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0  ...   61.0  53.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0  ...   57.0  45.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0  ...   59.0  46.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0  ...   64.0  58.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN  ...    NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 33 columns]

# %%
df['Preferred Position'].unique().tolist()
# Out:
# ['ST',
#  'RW',
#  'LW',
#  'GK',
#  'CDM',
#  'CB',
#  'RM',
#  'CM',
#  'LM',
#  'LB',
#  'CAM',
#  'RB',
#  'CF',
#  'RWB',
#  'LWB',
#  nan]

# %%
#df.loc['Preferred Position'].

# %%
df = df[df['Preferred Position'] == 'ST']

# %%
df.head()
# Out:
#                  Name  Age Nationality  Overall  Potential              Club  \
# 0   Cristiano Ronaldo   32    Portugal     94.0       94.0    Real Madrid CF
# 3          L. SuÃ¡rez   30     Uruguay     92.0       92.0      FC Barcelona
# 5      R. Lewandowski   28      Poland     91.0       91.0  FC Bayern Munich
# 9         G. HiguaÃ­n   29   Argentina     90.0       90.0          Juventus
# 16         S. AgÃ¼ero   29   Argentina     89.0       89.0   Manchester City
#
#    Preferred Position   CAM    CB   CDM  ...     RB   RCB   RCM   RDM    RF  \
# 0                  ST  89.0  53.0  62.0  ...   61.0  53.0  82.0  62.0  91.0
# 3                  ST  87.0  58.0  65.0  ...   64.0  58.0  80.0  65.0  88.0
# 5                  ST  84.0  57.0  62.0  ...   58.0  57.0  78.0  62.0  87.0
# 9                  ST  81.0  46.0  52.0  ...   51.0  46.0  71.0  52.0  84.0
# 16                 ST  85.0  44.0  54.0  ...   52.0  44.0  75.0  54.0  87.0
#
#       RM    RS    RW   RWB    ST
# 0   89.0  92.0  91.0  66.0  92.0
# 3   85.0  88.0  87.0  68.0  88.0
# 5   82.0  88.0  84.0  61.0  88.0
# 9   79.0  87.0  82.0  55.0  87.0
# 16  84.0  86.0  86.0  57.0  86.0
#
# [5 rows x 33 columns]

# %%
df = df.sort_values(by=['ST'], ascending=False)

# %%
df.head(10)
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 0   Cristiano Ronaldo   32    Portugal     94.0       94.0
# 5      R. Lewandowski   28      Poland     91.0       91.0
# 3          L. SuÃ¡rez   30     Uruguay     92.0       92.0
# 9         G. HiguaÃ­n   29   Argentina     90.0       90.0
# 16         S. AgÃ¼ero   29   Argentina     89.0       89.0
# 23      P. Aubameyang   28       Gabon     88.0       88.0
# 31    Z. IbrahimoviÄ   35      Sweden     88.0       88.0
# 38          E. Cavani   30     Uruguay     87.0       87.0
# 46            H. Kane   23     England     86.0       90.0
# 50          R. Lukaku   24     Belgium     86.0       90.0
#
#                    Club Preferred Position   CAM    CB   CDM  ...     RB  \
# 0        Real Madrid CF                 ST  89.0  53.0  62.0  ...   61.0
# 5      FC Bayern Munich                 ST  84.0  57.0  62.0  ...   58.0
# 3          FC Barcelona                 ST  87.0  58.0  65.0  ...   64.0
# 9              Juventus                 ST  81.0  46.0  52.0  ...   51.0
# 16      Manchester City                 ST  85.0  44.0  54.0  ...   52.0
# 23    Borussia Dortmund                 ST  82.0  52.0  59.0  ...   62.0
# 31    Manchester United                 ST  83.0  52.0  60.0  ...   54.0
# 38  Paris Saint-Germain                 ST  80.0  58.0  62.0  ...   61.0
# 46    Tottenham Hotspur                 ST  79.0  57.0  62.0  ...   60.0
# 50    Manchester United                 ST  77.0  53.0  57.0  ...   56.0
#
#      RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0   53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 5   57.0  78.0  62.0  87.0  82.0  88.0  84.0  61.0  88.0
# 3   58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 9   46.0  71.0  52.0  84.0  79.0  87.0  82.0  55.0  87.0
# 16  44.0  75.0  54.0  87.0  84.0  86.0  86.0  57.0  86.0
# 23  52.0  74.0  59.0  84.0  83.0  85.0  84.0  65.0  85.0
# 31  52.0  78.0  60.0  83.0  80.0  84.0  82.0  58.0  84.0
# 38  58.0  74.0  62.0  82.0  79.0  84.0  80.0  64.0  84.0
# 46  57.0  74.0  62.0  82.0  78.0  84.0  79.0  62.0  84.0
# 50  53.0  71.0  57.0  80.0  77.0  84.0  78.0  58.0  84.0
#
# [10 rows x 33 columns]

# %%
df = df.set_index(['Name'])

# %% [markdown]
# also can do ```reset_index()``` want to add argument ```drop=True``` in order to drop old index

# %%
df.head()
# Out:
#                    Age Nationality  Overall  Potential              Club  \
# Name
# Cristiano Ronaldo   32    Portugal     94.0       94.0    Real Madrid CF
# R. Lewandowski      28      Poland     91.0       91.0  FC Bayern Munich
# L. SuÃ¡rez          30     Uruguay     92.0       92.0      FC Barcelona
# G. HiguaÃ­n         29   Argentina     90.0       90.0          Juventus
# S. AgÃ¼ero          29   Argentina     89.0       89.0   Manchester City
#
#                   Preferred Position   CAM    CB   CDM    CF  ...     RB  \
# Name                                                          ...
# Cristiano Ronaldo                 ST  89.0  53.0  62.0  91.0  ...   61.0
# R. Lewandowski                    ST  84.0  57.0  62.0  87.0  ...   58.0
# L. SuÃ¡rez                        ST  87.0  58.0  65.0  88.0  ...   64.0
# G. HiguaÃ­n                       ST  81.0  46.0  52.0  84.0  ...   51.0
# S. AgÃ¼ero                        ST  85.0  44.0  54.0  87.0  ...   52.0
#
#                     RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# Name
# Cristiano Ronaldo  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# R. Lewandowski     57.0  78.0  62.0  87.0  82.0  88.0  84.0  61.0  88.0
# L. SuÃ¡rez         58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# G. HiguaÃ­n        46.0  71.0  52.0  84.0  79.0  87.0  82.0  55.0  87.0
# S. AgÃ¼ero         44.0  75.0  54.0  87.0  84.0  86.0  86.0  57.0  86.0
#
# [5 rows x 32 columns]

# %%
df = df.sort_values(by=['ST'])

# %%
worst = df.iloc[[0]]

# %%
print(worst)
# Out:
#             Age Nationality  Overall  Potential         Club  \
# Name
# O. Sowunmi   21     England     59.0       71.0  Yeovil Town
#
#            Preferred Position   CAM    CB   CDM    CF  ...     RB   RCB   RCM  \
# Name                                                   ...
# O. Sowunmi                 ST  35.0  58.0  47.0  38.0  ...   52.0  58.0  37.0
#
#              RDM    RF    RM    RS    RW   RWB    ST
# Name
# O. Sowunmi  47.0  38.0  38.0  44.0  37.0  49.0  44.0
#
# [1 rows x 32 columns]
